# %% [markdown]
# # Quickest Electric Cars Visualization

# %% [markdown]
# ## Import libraries and data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Check for the working directory
# !pwd
# Out:
# /Users/escortkwon/Code/Portfolio_Project_2021/Quickest Electric Cars

# %%
# Check for what files does certain directory have
# !ls
# Out:
# QuickestElectricCars.ipynb          archive.zip
# Quickestelectriccars-EVDatabase.csv

# %%
# Unzip for fetch data
# !unzip -o archive.zip
# Out:
# Archive:  archive.zip
#   inflating: Quickestelectriccars-EVDatabase.csv

# %%
cars = pd.read_csv('Quickestelectriccars-EVDatabase.csv')
cars
# Out:
#                                      Name  \
# 0                         Tesla Roadster
# 1                     Tesla Model X Plaid
# 2                  Porsche Taycan Turbo S
# 3    Porsche Taycan Turbo S Cross Turismo
# 4              Tesla Cybertruck Tri Motor
# ..                                    ...
# 174   Peugeot e-Traveller Standard 75 kWh
# 175       Peugeot e-Traveller Long 75 kWh
# 176                Nissan e-NV200 Evalia
# 177                 Dacia Spring Electric
# 178             Renault Kangoo Maxi ZE 33
#
#                                        Subtitle Acceleration  TopSpeed  \
# 0     Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h
# 1      Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h
# 2     Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h
# 3     Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h
# 4     Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h
# ..                                          ...          ...       ...
# 174    Battery Electric Vehicle |       68 kWh      13.3 sec  130 km/h
# 175    Battery Electric Vehicle |       68 kWh      13.3 sec  130 km/h
# 176    Battery Electric Vehicle |       36 kWh      14.0 sec  123 km/h
# 177  Battery Electric Vehicle |       26.8 kWh      15.0 sec  125 km/h
# 178    Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h
#
#       Range Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    970 km  206 Wh/km        920 km/h    All Wheel Drive              4
# 1    455 km  198 Wh/km        680 km/h    All Wheel Drive              7
# 2    390 km  215 Wh/km        860 km/h    All Wheel Drive              4
# 3    380 km  220 Wh/km        790 km/h    All Wheel Drive              4
# 4    750 km  267 Wh/km        710 km/h    All Wheel Drive              7
# ..      ...        ...             ...                ...            ...
# 174  270 km  252 Wh/km        290 km/h  Front Wheel Drive              7
# 175  270 km  252 Wh/km        290 km/h  Front Wheel Drive              7
# 176  165 km  218 Wh/km        170 km/h  Front Wheel Drive              7
# 177  170 km  158 Wh/km        120 km/h  Front Wheel Drive              4
# 178  160 km  194 Wh/km               -  Front Wheel Drive              5
#
#     PriceinGermany PriceinUK
# 0         €215,000  £189,000
# 1         €116,990  £110,980
# 2         €186,336  £138,830
# 3         €187,746  £139,910
# 4          €75,000   £68,000
# ..             ...       ...
# 174        €57,440       NaN
# 175        €58,230       NaN
# 176        €43,433   £30,255
# 177        €20,490       NaN
# 178            NaN   £31,680
#
# [179 rows x 11 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# Check null values by columns
cars.isnull().sum()
# Out:
# Name                0
# Subtitle            0
# Acceleration        0
# TopSpeed            0
# Range               0
# Efficiency          0
# FastChargeSpeed     0
# Drive               0
# NumberofSeats       0
# PriceinGermany     12
# PriceinUK          44
# dtype: int64

# %%
# Remove rows which has nulll values
cars.dropna(axis=0, inplace=True)
cars
# Out:
#                                      Name  \
# 0                         Tesla Roadster
# 1                     Tesla Model X Plaid
# 2                  Porsche Taycan Turbo S
# 3    Porsche Taycan Turbo S Cross Turismo
# 4              Tesla Cybertruck Tri Motor
# ..                                    ...
# 160                 Mercedes EQV 300 Long
# 165                     Smart EQ forfour
# 166   Peugeot e-Traveller Standard 50 kWh
# 167       Peugeot e-Traveller Long 50 kWh
# 176                Nissan e-NV200 Evalia
#
#                                        Subtitle Acceleration  TopSpeed  \
# 0     Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h
# 1      Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h
# 2     Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h
# 3     Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h
# 4     Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h
# ..                                          ...          ...       ...
# 160     Battery Electric Vehicle |       90 kWh     12.1 sec  160 km/h
# 165  Battery Electric Vehicle |       16.7 kWh      12.7 sec  130 km/h
# 166    Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h
# 167    Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h
# 176    Battery Electric Vehicle |       36 kWh      14.0 sec  123 km/h
#
#       Range Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    970 km  206 Wh/km        920 km/h    All Wheel Drive              4
# 1    455 km  198 Wh/km        680 km/h    All Wheel Drive              7
# 2    390 km  215 Wh/km        860 km/h    All Wheel Drive              4
# 3    380 km  220 Wh/km        790 km/h    All Wheel Drive              4
# 4    750 km  267 Wh/km        710 km/h    All Wheel Drive              7
# ..      ...        ...             ...                ...            ...
# 160  320 km  281 Wh/km        280 km/h  Front Wheel Drive              7
# 165   95 km  176 Wh/km               -   Rear Wheel Drive              4
# 166  185 km  243 Wh/km        250 km/h  Front Wheel Drive              7
# 167  185 km  243 Wh/km        250 km/h  Front Wheel Drive              7
# 176  165 km  218 Wh/km        170 km/h  Front Wheel Drive              7
#
#     PriceinGermany PriceinUK
# 0         €215,000  £189,000
# 1         €116,990  £110,980
# 2         €186,336  £138,830
# 3         €187,746  £139,910
# 4          €75,000   £68,000
# ..             ...       ...
# 160        €71,388   £70,665
# 165        €19,120   £19,795
# 166        €55,900   £49,065
# 167        €56,690   £49,905
# 176        €43,433   £30,255
#
# [126 rows x 11 columns]

# %%
# Remove rows which is '-'
idx = cars[cars['FastChargeSpeed'] == '-'].index
cars = cars.drop(idx)
cars
# Out:
#                                      Name  \
# 0                         Tesla Roadster
# 1                     Tesla Model X Plaid
# 2                  Porsche Taycan Turbo S
# 3    Porsche Taycan Turbo S Cross Turismo
# 4              Tesla Cybertruck Tri Motor
# ..                                    ...
# 158           Opel Zafira-e Life L 50 kWh
# 160                 Mercedes EQV 300 Long
# 166   Peugeot e-Traveller Standard 50 kWh
# 167       Peugeot e-Traveller Long 50 kWh
# 176                Nissan e-NV200 Evalia
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0    Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h  970 km
# 1     Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h  455 km
# 2    Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
# 3    Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h  380 km
# 4    Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h  750 km
# ..                                         ...          ...       ...     ...
# 158   Battery Electric Vehicle |       45 kWh      12.1 sec  130 km/h  180 km
# 160    Battery Electric Vehicle |       90 kWh     12.1 sec  160 km/h  320 km
# 166   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 167   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 176   Battery Electric Vehicle |       36 kWh      14.0 sec  123 km/h  165 km
#
#     Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    206 Wh/km        920 km/h    All Wheel Drive              4
# 1    198 Wh/km        680 km/h    All Wheel Drive              7
# 2    215 Wh/km        860 km/h    All Wheel Drive              4
# 3    220 Wh/km        790 km/h    All Wheel Drive              4
# 4    267 Wh/km        710 km/h    All Wheel Drive              7
# ..         ...             ...                ...            ...
# 158  250 Wh/km        240 km/h  Front Wheel Drive              7
# 160  281 Wh/km        280 km/h  Front Wheel Drive              7
# 166  243 Wh/km        250 km/h  Front Wheel Drive              7
# 167  243 Wh/km        250 km/h  Front Wheel Drive              7
# 176  218 Wh/km        170 km/h  Front Wheel Drive              7
#
#     PriceinGermany PriceinUK
# 0         €215,000  £189,000
# 1         €116,990  £110,980
# 2         €186,336  £138,830
# 3         €187,746  £139,910
# 4          €75,000   £68,000
# ..             ...       ...
# 158        €54,625   £49,465
# 160        €71,388   £70,665
# 166        €55,900   £49,065
# 167        €56,690   £49,905
# 176        €43,433   £30,255
#
# [123 rows x 11 columns]

# %%
# Reset index
cars.reset_index(drop=True, inplace=True)
cars
# Out:
#                                      Name  \
# 0                         Tesla Roadster
# 1                     Tesla Model X Plaid
# 2                  Porsche Taycan Turbo S
# 3    Porsche Taycan Turbo S Cross Turismo
# 4              Tesla Cybertruck Tri Motor
# ..                                    ...
# 118           Opel Zafira-e Life L 50 kWh
# 119                 Mercedes EQV 300 Long
# 120   Peugeot e-Traveller Standard 50 kWh
# 121       Peugeot e-Traveller Long 50 kWh
# 122                Nissan e-NV200 Evalia
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0    Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h  970 km
# 1     Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h  455 km
# 2    Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
# 3    Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h  380 km
# 4    Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h  750 km
# ..                                         ...          ...       ...     ...
# 118   Battery Electric Vehicle |       45 kWh      12.1 sec  130 km/h  180 km
# 119    Battery Electric Vehicle |       90 kWh     12.1 sec  160 km/h  320 km
# 120   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 121   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 122   Battery Electric Vehicle |       36 kWh      14.0 sec  123 km/h  165 km
#
#     Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    206 Wh/km        920 km/h    All Wheel Drive              4
# 1    198 Wh/km        680 km/h    All Wheel Drive              7
# 2    215 Wh/km        860 km/h    All Wheel Drive              4
# 3    220 Wh/km        790 km/h    All Wheel Drive              4
# 4    267 Wh/km        710 km/h    All Wheel Drive              7
# ..         ...             ...                ...            ...
# 118  250 Wh/km        240 km/h  Front Wheel Drive              7
# 119  281 Wh/km        280 km/h  Front Wheel Drive              7
# 120  243 Wh/km        250 km/h  Front Wheel Drive              7
# 121  243 Wh/km        250 km/h  Front Wheel Drive              7
# 122  218 Wh/km        170 km/h  Front Wheel Drive              7
#
#     PriceinGermany PriceinUK
# 0         €215,000  £189,000
# 1         €116,990  £110,980
# 2         €186,336  £138,830
# 3         €187,746  £139,910
# 4          €75,000   £68,000
# ..             ...       ...
# 118        €54,625   £49,465
# 119        €71,388   £70,665
# 120        €55,900   £49,065
# 121        €56,690   £49,905
# 122        €43,433   £30,255
#
# [123 rows x 11 columns]

# %%
# Create 'Compnay' Column
cars['Company'] = cars['Name'].str.split(' ').str[0]
cars
# Out:
#                                      Name  \
# 0                         Tesla Roadster
# 1                     Tesla Model X Plaid
# 2                  Porsche Taycan Turbo S
# 3    Porsche Taycan Turbo S Cross Turismo
# 4              Tesla Cybertruck Tri Motor
# ..                                    ...
# 118           Opel Zafira-e Life L 50 kWh
# 119                 Mercedes EQV 300 Long
# 120   Peugeot e-Traveller Standard 50 kWh
# 121       Peugeot e-Traveller Long 50 kWh
# 122                Nissan e-NV200 Evalia
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0    Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h  970 km
# 1     Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h  455 km
# 2    Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
# 3    Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h  380 km
# 4    Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h  750 km
# ..                                         ...          ...       ...     ...
# 118   Battery Electric Vehicle |       45 kWh      12.1 sec  130 km/h  180 km
# 119    Battery Electric Vehicle |       90 kWh     12.1 sec  160 km/h  320 km
# 120   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 121   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 122   Battery Electric Vehicle |       36 kWh      14.0 sec  123 km/h  165 km
#
#     Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    206 Wh/km        920 km/h    All Wheel Drive              4
# 1    198 Wh/km        680 km/h    All Wheel Drive              7
# 2    215 Wh/km        860 km/h    All Wheel Drive              4
# 3    220 Wh/km        790 km/h    All Wheel Drive              4
# 4    267 Wh/km        710 km/h    All Wheel Drive              7
# ..         ...             ...                ...            ...
# 118  250 Wh/km        240 km/h  Front Wheel Drive              7
# 119  281 Wh/km        280 km/h  Front Wheel Drive              7
# 120  243 Wh/km        250 km/h  Front Wheel Drive              7
# 121  243 Wh/km        250 km/h  Front Wheel Drive              7
# 122  218 Wh/km        170 km/h  Front Wheel Drive              7
#
#     PriceinGermany PriceinUK   Company
# 0         €215,000  £189,000     Tesla
# 1         €116,990  £110,980     Tesla
# 2         €186,336  £138,830   Porsche
# 3         €187,746  £139,910   Porsche
# 4          €75,000   £68,000     Tesla
# ..             ...       ...       ...
# 118        €54,625   £49,465      Opel
# 119        €71,388   £70,665  Mercedes
# 120        €55,900   £49,065   Peugeot
# 121        €56,690   £49,905   Peugeot
# 122        €43,433   £30,255    Nissan
#
# [123 rows x 12 columns]

# %%
# Remove units of each column
cars['BatteryCapacity[kWh]'] = cars['Subtitle'].str.extract(r'(\d+[.\d]*)').astype(float)
cars['Acceleration[sec]'] = cars['Acceleration'].str.extract(r'(\d+[.\d]*)').astype(float)
cars['TopSpeed[km/h]'] = cars['TopSpeed'].str.extract(r'(\d+)').astype(int)
cars['Range[km]'] = cars['Range'].str.extract(r'(\d+)').astype(int)
cars['Efficiency[Wh/km]'] = cars['Efficiency'].str.extract(r'(\d+)').astype(int)
cars['FastChargeSpeed[km/h]'] = cars['FastChargeSpeed'].str.extract(r'(\d+)').astype(int)
cars['Drive_Class'] = cars['Drive'].str.split(' ').str[0]
cars['PriceinGermany[€]'] = cars['PriceinGermany'].str.replace(pat=r'[^\w]', repl=r'', regex=True).astype(int)
cars['PriceinUK[£]'] = cars['PriceinUK'].str.replace(pat=r'[^\w]', repl=r'', regex=True).astype(int)

cars
# Out:
#                                      Name  \
# 0                         Tesla Roadster
# 1                     Tesla Model X Plaid
# 2                  Porsche Taycan Turbo S
# 3    Porsche Taycan Turbo S Cross Turismo
# 4              Tesla Cybertruck Tri Motor
# ..                                    ...
# 118           Opel Zafira-e Life L 50 kWh
# 119                 Mercedes EQV 300 Long
# 120   Peugeot e-Traveller Standard 50 kWh
# 121       Peugeot e-Traveller Long 50 kWh
# 122                Nissan e-NV200 Evalia
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0    Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h  970 km
# 1     Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h  455 km
# 2    Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
# 3    Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h  380 km
# 4    Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h  750 km
# ..                                         ...          ...       ...     ...
# 118   Battery Electric Vehicle |       45 kWh      12.1 sec  130 km/h  180 km
# 119    Battery Electric Vehicle |       90 kWh     12.1 sec  160 km/h  320 km
# 120   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 121   Battery Electric Vehicle |       45 kWh      13.1 sec  130 km/h  185 km
# 122   Battery Electric Vehicle |       36 kWh      14.0 sec  123 km/h  165 km
#
#     Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    206 Wh/km        920 km/h    All Wheel Drive              4
# 1    198 Wh/km        680 km/h    All Wheel Drive              7
# 2    215 Wh/km        860 km/h    All Wheel Drive              4
# 3    220 Wh/km        790 km/h    All Wheel Drive              4
# 4    267 Wh/km        710 km/h    All Wheel Drive              7
# ..         ...             ...                ...            ...
# 118  250 Wh/km        240 km/h  Front Wheel Drive              7
# 119  281 Wh/km        280 km/h  Front Wheel Drive              7
# 120  243 Wh/km        250 km/h  Front Wheel Drive              7
# 121  243 Wh/km        250 km/h  Front Wheel Drive              7
# 122  218 Wh/km        170 km/h  Front Wheel Drive              7
#
#     PriceinGermany  ...   Company BatteryCapacity[kWh]  Acceleration[sec]  \
# 0         €215,000  ...     Tesla                200.0                2.1
# 1         €116,990  ...     Tesla                 90.0                2.6
# 2         €186,336  ...   Porsche                 83.7                2.8
# 3         €187,746  ...   Porsche                 83.7                2.9
# 4          €75,000  ...     Tesla                200.0                3.0
# ..             ...  ...       ...                  ...                ...
# 118        €54,625  ...      Opel                 45.0               12.1
# 119        €71,388  ...  Mercedes                 90.0               12.1
# 120        €55,900  ...   Peugeot                 45.0               13.1
# 121        €56,690  ...   Peugeot                 45.0               13.1
# 122        €43,433  ...    Nissan                 36.0               14.0
#
#      TopSpeed[km/h]  Range[km]  Efficiency[Wh/km]  FastChargeSpeed[km/h]  \
# 0               410        970                206                    920
# 1               262        455                198                    680
# 2               260        390                215                    860
# 3               250        380                220                    790
# 4               210        750                267                    710
# ..              ...        ...                ...                    ...
# 118             130        180                250                    240
# 119             160        320                281                    280
# 120             130        185                243                    250
# 121             130        185                243                    250
# 122             123        165                218                    170
#
#      Drive_Class PriceinGermany[€]  PriceinUK[£]
# 0            All            215000        189000
# 1            All            116990        110980
# 2            All            186336        138830
# 3            All            187746        139910
# 4            All             75000         68000
# ..           ...               ...           ...
# 118        Front             54625         49465
# 119        Front             71388         70665
# 120        Front             55900         49065
# 121        Front             56690         49905
# 122        Front             43433         30255
#
# [123 rows x 21 columns]

# %%
# Remove old ones
cars.drop(['Subtitle', 'Acceleration', 'TopSpeed', 'Range', 'Efficiency', 'FastChargeSpeed', 'Drive', 'NumberofSeats', 'PriceinGermany', 'PriceinUK'], axis=1, inplace=True)
cars
# Out:
#                                      Name   Company  BatteryCapacity[kWh]  \
# 0                         Tesla Roadster      Tesla                 200.0
# 1                     Tesla Model X Plaid     Tesla                  90.0
# 2                  Porsche Taycan Turbo S   Porsche                  83.7
# 3    Porsche Taycan Turbo S Cross Turismo   Porsche                  83.7
# 4              Tesla Cybertruck Tri Motor     Tesla                 200.0
# ..                                    ...       ...                   ...
# 118           Opel Zafira-e Life L 50 kWh      Opel                  45.0
# 119                 Mercedes EQV 300 Long  Mercedes                  90.0
# 120   Peugeot e-Traveller Standard 50 kWh   Peugeot                  45.0
# 121       Peugeot e-Traveller Long 50 kWh   Peugeot                  45.0
# 122                Nissan e-NV200 Evalia     Nissan                  36.0
#
#      Acceleration[sec]  TopSpeed[km/h]  Range[km]  Efficiency[Wh/km]  \
# 0                  2.1             410        970                206
# 1                  2.6             262        455                198
# 2                  2.8             260        390                215
# 3                  2.9             250        380                220
# 4                  3.0             210        750                267
# ..                 ...             ...        ...                ...
# 118               12.1             130        180                250
# 119               12.1             160        320                281
# 120               13.1             130        185                243
# 121               13.1             130        185                243
# 122               14.0             123        165                218
#
#      FastChargeSpeed[km/h] Drive_Class  PriceinGermany[€]  PriceinUK[£]
# 0                      920         All             215000        189000
# 1                      680         All             116990        110980
# 2                      860         All             186336        138830
# 3                      790         All             187746        139910
# 4                      710         All              75000         68000
# ..                     ...         ...                ...           ...
# 118                    240       Front              54625         49465
# 119                    280       Front              71388         70665
# 120                    250       Front              55900         49065
# 121                    250       Front              56690         49905
# 122                    170       Front              43433         30255
#
# [123 rows x 11 columns]

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Heatmap

# %% [markdown]
# #### Heatmap across the DataFrame

# %%
# Create groupby processed DataFrame
# We can visualize between all features and companies
cars_groupby = cars.groupby('Company').mean()
cars_groupby
# Out:
#             BatteryCapacity[kWh]  Acceleration[sec]  TopSpeed[km/h]  \
# Company
# Audi                   73.200000           6.263636      194.090909
# BMW                    69.628571           5.900000      186.428571
# Byton                  87.333333           6.833333      190.000000
# CUPRA                  59.500000           7.450000      160.000000
# Citroen                45.000000          10.900000      140.000000
# DS                     45.000000           8.700000      150.000000
# Fiat                   32.800000           9.166667      145.000000
# Ford                   78.000000           6.500000      180.000000
# Honda                  28.500000           8.650000      145.000000
# Hyundai                59.614286           7.685714      175.285714
# Jaguar                 84.700000           4.800000      200.000000
# Kia                    65.566667           7.083333      189.500000
# Lexus                  50.000000           7.500000      160.000000
# Lucid                  93.333333           3.600000      240.000000
# MG                     42.500000           8.200000      140.000000
# Mazda                  30.000000           9.700000      140.000000
# Mercedes               86.433333           7.183333      180.000000
# Mini                   28.900000           7.300000      150.000000
# Nissan                 64.375000           7.625000      168.000000
# Opel                   45.000000           9.566667      143.333333
# Peugeot                45.000000          11.033333      138.333333
# Polestar               70.333333           6.500000      175.000000
# Porsche                81.160000           4.020000      244.000000
# Renault                54.666667           9.633333      145.000000
# Skoda                  72.250000           7.600000      165.000000
# Tesla                 101.583333           4.175000      243.416667
# Volkswagen             62.000000           8.537500      162.500000
# Volvo                  75.000000           4.800000      180.000000
#
#              Range[km]  Efficiency[Wh/km]  FastChargeSpeed[km/h]  \
# Company
# Audi        347.272727         211.727273             538.181818
# BMW         375.714286         182.571429             490.000000
# Byton       371.666667         234.666667             453.333333
# CUPRA       355.000000         167.250000             465.000000
# Citroen     217.500000         211.500000             290.000000
# DS          250.000000         180.000000             330.000000
# Fiat        220.000000         148.333333             363.333333
# Ford        383.750000         203.250000             395.000000
# Honda       170.000000         168.000000             190.000000
# Hyundai     333.571429         176.857143             591.428571
# Jaguar      365.000000         232.000000             340.000000
# Kia         358.333333         181.666667             695.000000
# Lexus       260.000000         192.000000             150.000000
# Lucid       576.666667         161.333333            1393.333333
# MG          220.000000         193.000000             260.000000
# Mazda       170.000000         176.000000             180.000000
# Mercedes    439.166667         204.166667             530.000000
# Mini        185.000000         156.000000             260.000000
# Nissan      327.500000         195.625000             396.250000
# Opel        236.666667         196.666667             316.666667
# Peugeot     215.000000         214.333333             288.333333
# Polestar    390.000000         180.000000             503.333333
# Porsche     403.000000         201.800000             840.000000
# Renault     320.000000         170.666667             313.333333
# Skoda       387.500000         186.000000             477.500000
# Tesla       507.083333         195.333333             734.166667
# Volkswagen  350.625000         176.500000             437.500000
# Volvo       340.000000         221.000000             440.000000
#
#             PriceinGermany[€]  PriceinUK[£]
# Company
# Audi             73709.090909  66225.454545
# BMW              64485.714286  57154.285714
# Byton            59833.333333  55833.333333
# CUPRA            37867.500000  33125.000000
# Citroen          43040.000000  31445.000000
# DS               30040.000000  31500.000000
# Fiat             27226.666667  23711.666667
# Ford             54568.750000  48747.500000
# Honda            35925.000000  28910.000000
# Hyundai          44042.857143  37590.714286
# Jaguar           77300.000000  65195.000000
# Kia              49391.666667  43678.333333
# Lexus            47550.000000  43900.000000
# Lucid           105000.000000  95000.000000
# MG               31990.000000  25995.000000
# Mazda            34490.000000  26045.000000
# Mercedes         81150.166667  73313.333333
# Mini             32500.000000  26000.000000
# Nissan           47409.125000  40836.875000
# Opel             39245.000000  35715.000000
# Peugeot          43111.666667  36625.833333
# Polestar         49500.000000  42900.000000
# Porsche         127927.800000  99591.200000
# Renault          34660.000000  29363.333333
# Skoda            44950.000000  39586.250000
# Tesla            80215.000000  73825.833333
# Volkswagen       39463.750000  36171.250000
# Volvo            60650.000000  53675.000000

# %%
# Normalization
# Unit of each columns is differenct each other.
# Therfore, with Normalization, we can compare columns with same level
def mean_norm(df_input):
    return df_input.apply(lambda x: (x - x.mean()) / x.std(), axis=0)

cars_norm = mean_norm(cars_groupby)
cars_norm
# Out:
#             BatteryCapacity[kWh]  Acceleration[sec]  TopSpeed[km/h]  \
# Company
# Audi                    0.555270          -0.572743        0.697926
# BMW                     0.380778          -0.757725        0.450287
# Byton                   1.245790          -0.282938        0.565712
# CUPRA                  -0.114079           0.030761       -0.403860
# Citroen                -0.822513           1.785778       -1.050241
# DS                     -0.822513           0.666637       -0.727050
# Fiat                   -1.418575           0.904030       -0.888645
# Ford                    0.789786          -0.452505        0.242522
# Honda                  -1.628662           0.641202       -0.888645
# Hyundai                -0.108495           0.150669        0.090160
# Jaguar                  1.117131          -1.317296        0.888903
# Kia                     0.182324          -0.155763        0.549553
# Lexus                  -0.578225           0.056196       -0.403860
# Lucid                   1.538935          -1.927736        2.181665
# MG                     -0.944657           0.412286       -1.050241
# Mazda                  -1.555376           1.175337       -1.050241
# Mercedes                1.201818          -0.104893        0.242522
# Mini                   -1.609119          -0.045544       -0.727050
# Nissan                  0.124102           0.119784       -0.145307
# Opel                   -0.822513           1.107511       -0.942510
# Peugeot                -0.822513           1.853605       -1.104106
# Polestar                0.415211          -0.452505        0.080926
# Porsche                 0.944176          -1.714082        2.310941
# Renault                -0.350223           1.141424       -0.888645
# Skoda                   0.508855           0.107066       -0.242264
# Tesla                   1.942009          -1.635234        2.292088
# Volkswagen              0.008065           0.583973       -0.323062
# Volvo                   0.643213          -1.317296        0.242522
#
#             Range[km]  Efficiency[Wh/km]  FastChargeSpeed[km/h]  \
# Company
# Audi         0.232144           0.998414               0.347452
# BMW          0.517607          -0.337510               0.152742
# Byton        0.476982           2.049500               0.004566
# CUPRA        0.309701          -1.039540               0.051713
# Citroen     -1.070360           0.988000              -0.655489
# DS          -0.744164          -0.455333              -0.493842
# Fiat        -1.045268          -1.906304              -0.359137
# Ford         0.598260           0.609984              -0.231167
# Honda       -1.547109          -1.005175              -1.059604
# Hyundai      0.094627          -0.599339               0.562630
# Jaguar       0.410069           1.927313              -0.453431
# Kia          0.343157          -0.378967               0.981178
# Lexus       -0.643796           0.094508              -1.221250
# Lucid        2.534528          -1.310642               3.803251
# MG          -1.045268           0.140328              -0.776723
# Mazda       -1.547109          -0.638614              -1.100015
# Mercedes     1.154466           0.651986               0.314388
# Mini        -1.396557          -1.555016              -0.776723
# Nissan       0.033689           0.260606              -0.226116
# Opel        -0.877988           0.308335              -0.547725
# Peugeot     -1.095452           1.117824              -0.662224
# Polestar     0.660990          -0.455333               0.206624
# Porsche      0.791468           0.543545               1.567146
# Renault     -0.041587          -0.882988              -0.561195
# Skoda        0.635898          -0.180413               0.102228
# Tesla        1.836133           0.247242               1.139457
# Volkswagen   0.265790          -0.615704              -0.059418
# Volvo        0.159149           1.423292              -0.049316
#
#             PriceinGermany[€]  PriceinUK[£]
# Company
# Audi                 0.854081      0.971189
# BMW                  0.464801      0.524842
# Byton                0.268444      0.459844
# CUPRA               -0.658641     -0.657520
# Citroen             -0.440331     -0.740185
# DS                  -0.989006     -0.737478
# Fiat                -1.107745     -1.120703
# Ford                 0.046248      0.111185
# Honda               -0.740625     -0.864919
# Hyundai             -0.398005     -0.437785
# Jaguar               1.005638      0.920485
# Kia                 -0.172254     -0.138243
# Lexus               -0.249983     -0.127336
# Lucid                2.174737      2.387041
# MG                  -0.906705     -1.008352
# Mazda               -0.801190     -1.005892
# Mercedes             1.168137      1.319948
# Mini                -0.885180     -1.008106
# Nissan              -0.255929     -0.278057
# Opel                -0.600502     -0.530079
# Peugeot             -0.437307     -0.485262
# Polestar            -0.167682     -0.176541
# Porsche              3.142422      2.612951
# Renault             -0.794015     -0.842613
# Skoda               -0.359718     -0.339594
# Tesla                1.128668      1.345166
# Volkswagen          -0.591270     -0.507629
# Volvo                0.302912      0.353643

# %%
# Heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(data=cars_norm, linewidths=.5, cmap="YlGnBu")
plt.title('Feature - Companies')
plt.show()

# %% [markdown]
# #### Heatmap Drive_Class - Companies

# %%
# Function which creates Pivot Table
# We can choose Feature which we want to select
def cars_pivot(data, index, columns, values):
    global cars_pt
    cars_pt = pd.pivot_table(data=data, index=index, columns=columns, values=values, aggfunc='mean', fill_value=0)

cars_pivot(cars, 'Company', 'Drive_Class', 'BatteryCapacity[kWh]')

# %%
cars_pt
# Out:
# Drive_Class         All      Front        Rear
# Company
# Audi          78.200000   0.000000   59.866667
# BMW           85.633333   0.000000   57.625000
# Byton         95.000000   0.000000   83.500000
# CUPRA          0.000000   0.000000   59.500000
# Citroen        0.000000  45.000000    0.000000
# DS             0.000000  45.000000    0.000000
# Fiat           0.000000  32.800000    0.000000
# Ford          78.000000   0.000000   78.000000
# Honda          0.000000   0.000000   28.500000
# Hyundai       72.600000  47.166667   65.300000
# Jaguar        84.700000   0.000000    0.000000
# Kia           77.400000  51.600000   67.700000
# Lexus          0.000000  50.000000    0.000000
# Lucid         97.500000   0.000000   85.000000
# MG             0.000000  42.500000    0.000000
# Mazda          0.000000  30.000000    0.000000
# Mercedes      84.766667  78.250000  107.800000
# Mini           0.000000  28.900000    0.000000
# Nissan        79.000000  55.600000    0.000000
# Opel           0.000000  45.000000    0.000000
# Peugeot        0.000000  45.000000    0.000000
# Polestar      75.000000  68.000000    0.000000
# Porsche       82.112500   0.000000   77.350000
# Renault        0.000000  54.666667    0.000000
# Skoda         77.000000   0.000000   67.500000
# Tesla        113.111111   0.000000   67.000000
# Volkswagen    77.000000   0.000000   59.857143
# Volvo         75.000000   0.000000    0.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(data=cars_pt, annot=True, annot_kws={"size":10}, linewidths=.5, cmap="YlGnBu", fmt="")
plt.title('Drive_Class - Companies')
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
cars_BatteryCapacity = cars.sort_values(by='BatteryCapacity[kWh]', ascending=False)
cars_BatteryCapacity
# Out:
#                             Name   Company  BatteryCapacity[kWh]  \
# 0                Tesla Roadster      Tesla                 200.0
# 4     Tesla Cybertruck Tri Motor     Tesla                 200.0
# 29   Tesla Cybertruck Dual Motor     Tesla                 120.0
# 5        Lucid Air Grand Touring     Lucid                 110.0
# 21       Mercedes EQS 580 4MATIC  Mercedes                 107.8
# ..                           ...       ...                   ...
# 110                 Mazda MX-30      Mazda                  30.0
# 67               Mini Cooper SE       Mini                  28.9
# 86               Honda e Advance     Honda                  28.5
# 102                     Honda e      Honda                  28.5
# 105   Fiat 500e Hatchback 24 kWh      Fiat                  23.8
#
#      Acceleration[sec]  TopSpeed[km/h]  Range[km]  Efficiency[Wh/km]  \
# 0                  2.1             410        970                206
# 4                  3.0             210        750                267
# 29                 5.0             190        460                261
# 5                  3.2             270        660                167
# 21                 4.3             210        610                177
# ..                 ...             ...        ...                ...
# 110                9.7             140        170                176
# 67                 7.3             150        185                156
# 86                 8.3             145        170                168
# 102                9.0             145        170                168
# 105                9.5             135        165                144
#
#      FastChargeSpeed[km/h] Drive_Class  PriceinGermany[€]  PriceinUK[£]
# 0                      920         All             215000        189000
# 4                      710         All              75000         68000
# 29                     710         All              55000         48000
# 5                     1380         All             140000        125000
# 21                     800         All             135529        115000
# ..                     ...         ...                ...           ...
# 110                    180       Front              34490         26045
# 67                     260       Front              32500         26000
# 86                     190        Rear              38000         30160
# 102                    190        Rear              33850         27660
# 105                    260       Front              23560         20495
#
# [123 rows x 11 columns]

# %%
# Single Plot

sns.set_theme(style='whitegrid')
fig, ax = plt.subplots(figsize=(18, 18))
sns.barplot(x='BatteryCapacity[kWh]', y='Company', data=cars_BatteryCapacity, color='b')
plt.title('Companies - BatteryCapacity[kWh]', fontdict={'size': 20})

plt.show()

# %%
# All features are important
# But most of all, Battery Capacity and Range is more considered when we choose electric cars
# Multiplots
cars_norm_sorted = cars_norm.sort_values(by=['BatteryCapacity[kWh]', 'Range[km]'], ascending=False)
cars_norm_sorted.reset_index(inplace=True)
cars_norm_sorted
# Out:
#        Company  BatteryCapacity[kWh]  Acceleration[sec]  TopSpeed[km/h]  \
# 0        Tesla              1.942009          -1.635234        2.292088
# 1        Lucid              1.538935          -1.927736        2.181665
# 2        Byton              1.245790          -0.282938        0.565712
# 3     Mercedes              1.201818          -0.104893        0.242522
# 4       Jaguar              1.117131          -1.317296        0.888903
# 5      Porsche              0.944176          -1.714082        2.310941
# 6         Ford              0.789786          -0.452505        0.242522
# 7        Volvo              0.643213          -1.317296        0.242522
# 8         Audi              0.555270          -0.572743        0.697926
# 9        Skoda              0.508855           0.107066       -0.242264
# 10    Polestar              0.415211          -0.452505        0.080926
# 11         BMW              0.380778          -0.757725        0.450287
# 12         Kia              0.182324          -0.155763        0.549553
# 13      Nissan              0.124102           0.119784       -0.145307
# 14  Volkswagen              0.008065           0.583973       -0.323062
# 15     Hyundai             -0.108495           0.150669        0.090160
# 16       CUPRA             -0.114079           0.030761       -0.403860
# 17     Renault             -0.350223           1.141424       -0.888645
# 18       Lexus             -0.578225           0.056196       -0.403860
# 19          DS             -0.822513           0.666637       -0.727050
# 20        Opel             -0.822513           1.107511       -0.942510
# 21     Citroen             -0.822513           1.785778       -1.050241
# 22     Peugeot             -0.822513           1.853605       -1.104106
# 23          MG             -0.944657           0.412286       -1.050241
# 24        Fiat             -1.418575           0.904030       -0.888645
# 25       Mazda             -1.555376           1.175337       -1.050241
# 26        Mini             -1.609119          -0.045544       -0.727050
# 27       Honda             -1.628662           0.641202       -0.888645
#
#     Range[km]  Efficiency[Wh/km]  FastChargeSpeed[km/h]  PriceinGermany[€]  \
# 0    1.836133           0.247242               1.139457           1.128668
# 1    2.534528          -1.310642               3.803251           2.174737
# 2    0.476982           2.049500               0.004566           0.268444
# 3    1.154466           0.651986               0.314388           1.168137
# 4    0.410069           1.927313              -0.453431           1.005638
# 5    0.791468           0.543545               1.567146           3.142422
# 6    0.598260           0.609984              -0.231167           0.046248
# 7    0.159149           1.423292              -0.049316           0.302912
# 8    0.232144           0.998414               0.347452           0.854081
# 9    0.635898          -0.180413               0.102228          -0.359718
# 10   0.660990          -0.455333               0.206624          -0.167682
# 11   0.517607          -0.337510               0.152742           0.464801
# 12   0.343157          -0.378967               0.981178          -0.172254
# 13   0.033689           0.260606              -0.226116          -0.255929
# 14   0.265790          -0.615704              -0.059418          -0.591270
# 15   0.094627          -0.599339               0.562630          -0.398005
# 16   0.309701          -1.039540               0.051713          -0.658641
# 17  -0.041587          -0.882988              -0.561195          -0.794015
# 18  -0.643796           0.094508              -1.221250          -0.249983
# 19  -0.744164          -0.455333              -0.493842          -0.989006
# 20  -0.877988           0.308335              -0.547725          -0.600502
# 21  -1.070360           0.988000              -0.655489          -0.440331
# 22  -1.095452           1.117824              -0.662224          -0.437307
# 23  -1.045268           0.140328              -0.776723          -0.906705
# 24  -1.045268          -1.906304              -0.359137          -1.107745
# 25  -1.547109          -0.638614              -1.100015          -0.801190
# 26  -1.396557          -1.555016              -0.776723          -0.885180
# 27  -1.547109          -1.005175              -1.059604          -0.740625
#
#     PriceinUK[£]
# 0       1.345166
# 1       2.387041
# 2       0.459844
# 3       1.319948
# 4       0.920485
# 5       2.612951
# 6       0.111185
# 7       0.353643
# 8       0.971189
# 9      -0.339594
# 10     -0.176541
# 11      0.524842
# 12     -0.138243
# 13     -0.278057
# 14     -0.507629
# 15     -0.437785
# 16     -0.657520
# 17     -0.842613
# 18     -0.127336
# 19     -0.737478
# 20     -0.530079
# 21     -0.740185
# 22     -0.485262
# 23     -1.008352
# 24     -1.120703
# 25     -1.005892
# 26     -1.008106
# 27     -0.864919

# %%
# Batplots with multi index: BatteryCapacity[kWh], Range[km]

sns.set_theme(style='whitegrid')

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Plot the BatteryCapacity[kWh]
sns.set_color_codes("pastel")
sns.barplot(x='BatteryCapacity[kWh]', y='Company', data=cars_norm_sorted, label='BatteryCapacity[kWh]', color='b')

# Plot the Range[km]
sns.set_color_codes("muted")
sns.barplot(x='Range[km]', y='Company', data=cars_norm_sorted, label='Range[km]', color='b')

# Add a legend and informative axis label
ax.legend(ncol=2, loc='lower right', frameon=True)
ax.set(xlim=(-2, 3), xlabel='Features', ylabel='Company', title='Feature by Companies')
sns.despine(left=True, bottom=True)

plt.show()

# %%
# Price Compairson between Germany and UK

f, ax = plt.subplots(figsize=(15, 15))
sns.distplot(cars_norm_sorted['PriceinGermany[€]'], hist=False, label='PriceinGermany[€]')
sns.distplot(cars_norm_sorted['PriceinUK[£]'], hist=False, label='PriceinUK[£]')

ax.legend(ncol=2, loc='lower right', frameon=True)
ax.set(xlim=(-2, 3), xlabel='Company', ylabel='Price', title='Price Compairson between Germany and UK')
sns.despine(left=True, bottom=True)
# Out:
# /Users/escortkwon/miniforge3/envs/Drill_DL_TF/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/escortkwon/miniforge3/envs/Drill_DL_TF/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
